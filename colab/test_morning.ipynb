# %% [markdown]
# <a href="https://colab.research.google.com/github/mrella/finance/blob/main/test_morning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver

from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')


import pytest
import time
import json
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options





options.add_argument("--headless")  # Run without opening the browser
options.add_argument("--disable-gpu")  # Improve stability in some systems
options.add_argument("--window-size=1920x1080")  # Set window size for proper rendering
options.add_argument("--mute-audio")


driver = webdriver.Chrome(options=options)
driver.get("https://www.morningstar.es/es/portfoliomanager/portfolio.aspx")
#driver.set_window_size(800, 1000)
driver.set_window_size(1440, 1080)
driver.implicitly_wait(10)
driver.find_element(By.ID, "onetrust-accept-btn-handler").click()
driver.implicitly_wait(5)
driver.find_element(By.ID, "btn_individual").click()
driver.implicitly_wait(5)
driver.find_element(By.ID, "link2").click()
driver.find_element(By.ID, "username").send_keys("@.com")
driver.find_element(By.NAME, "action").click()
#driver.find_element(By.CSS_SELECTOR, ".hide").send_keys("")
driver.find_element(By.ID, "password").send_keys("")
driver.find_element(By.NAME, "action").click()
driver.implicitly_wait(5)


inicial = 480000
valor = float((driver.find_element(By.XPATH, "//tr[@class='gridFooter']/td[5]").text).replace(".","").replace(",","."))


winned = valor-inicial
from datetime import datetime

# Obtener la fecha actual
hoy = datetime.today()

# Calcular días transcurridos
dias_transcurridos = hoy.timetuple().tm_yday

print(int(winned/dias_transcurridos))


import requests

class SendTelegram:
    BOT_TOKEN = "7823072621:AAHG2Id8hylX8RWo"
    CHAT_ID = "165"

    @staticmethod
    def send(message):
        try:
            url = f"https://api.telegram.org/bot{SendTelegram.BOT_TOKEN}/sendMessage"
            payload = {
                "chat_id": SendTelegram.CHAT_ID,
                "text": message
            }
            response = requests.post(url, data=payload)

            print(f"Response Code: {response.status_code}")
            if response.ok:
                print("Message sent successfully")
            else:
                print("Error:", response.text)

        except Exception as e:
            print("Exception:", e)


SendTelegram.send(str(int(winned/dias_transcurridos)) + "=" + str(int(winned)) + "/" + str(dias_transcurridos) )
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 35.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 13.5 MB/s eta 0:00:00
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,833 kB]
# ...
